# %% [markdown]
# Part 1

# %%
from tokenize import group

import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
# df['FamilySize']
# df['IsAlone'] = df['FamilySize'] == 1


# pd.concat([df.head(5), df.tail(5)])
# df.shape
# df.dtypes
# df.describe
# numeric_df = df.select_dtypes(include='number')
# catego_df = df.select_dtypes(include='object')
# print(numeric_df.describe)
# print(catego_df.describe)
# df.isna().sum()
# missing_pct_df = (df.isna().sum() / len(df)) * 100
# missing_pct_df

# %% [markdown]
# Part 2

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

# df[['Name', 'Sex', 'Age', 'Survived']]
# df[df['Pclass'] == 1]
# df[df['Age'] > 60]
# df[(df['Sex'] == 'female') & (df['Survived'] == 1) & (df['Pclass'] == 3)]
# df.loc[df['Age'].isna(), ['Name', 'Age']]
# df.iloc[10:21, 0:3]
# df.loc[df['Age'].idxmin()]
# df.loc[df['Age'].idxmax()]

# %% [markdown]
# Part 3

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# df['Age'].isna()
# df['Age'] = df['Age'].fillna(df['Age'].mean())
# df['Age'].isna()
# df['Embarked'].isna()
# df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode())
# df['Embarked']
# df['Has_Cabin'] = df['Cabin'].isna()
# df['Has_Cabin']
# df.drop(columns='Cabin')
# df.drop_duplicates()
# df.isna()

# %% [markdown]
# Part 4

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
# df['FamilySize']
# df['IsAlone'] = df['FamilySize'] == 1
# df['Title'] = df['Name'].str.extract(r',([^.]+)\.')
# df['Title']
# df['Rare'] = df['Name'].str.extract(r'\b(Capt|Countess|Lady|Col|Don|Dr|Major|Rev|Sir|Jonkheer| Dona)\b')
# df['Rare']
# df['AgeGroup'] = df['Age']
# df['AgeGroup']
# df[df['Survived'] == 1]
# male = 100
# female
# print(df['Sex'])
# df.groupby('Pclass').agg({
#     'PassengerId':'count'
# })
# df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491
