# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load the raw dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# 2. Replay the transformations from the Pandas solution, in order
df['Age'] = df['Age'].fillna(0)
df['Adult'] = df['Age'] >= 18
df['Fare_double'] = df['Fare'] * 2

df = df.rename(columns={'Sex': 'Genre'})
df = df.drop(columns=['Ticket'])
df['Survived_text'] = df['Survived'].map({1: 'Yes', 0: 'No'})
df['Fare'] = df['Fare'].round(2)

# Optional but recommended global style
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (8, 5)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Genre   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch   Fare Cabin Embarked  Adult  Fare_double Survived_text
# 0      0   7.25   NaN        S   True      14.5000            No
# 1      0  71.28   C85        C   True     142.5666           Yes
# 2      0   7.92   NaN        S   True      15.8500           Yes
# ...

# %% [markdown]
# Part 1

# %%
df['Age'].hist(bins=30)

df_filtered_age = df[df["Age"] > 0]
df_filtered_age["Age"].hist( bins=30)


pclass_counts = df["Pclass"].value_counts().sort_index()

indx = ['1','2','3']

plt.figure(figsize=(8, 5))
plt.bar(
    indx,
    pclass_counts.values,
    color=["red", "blue", "green"],
)

zero_age_df = df[df["Age"] != 0]
money = zero_age["Fare"]

x = zero_age_df['Age']


plt.scatter(x,money,color = zero_age_df['Survived'].map({0:'red',1:'green'}))
